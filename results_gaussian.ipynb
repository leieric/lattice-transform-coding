# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
matplotlib.rcParams["text.usetex"] = True
matplotlib.rcParams["text.latex.preamble"] += r'\usepackage{xfrac}'
matplotlib.rcParams["text.latex.preamble"] += r'\usepackage{bm}'
matplotlib.rcParams.update({'font.size': 18})
matplotlib.rcParams["lines.linewidth"] = 1.5
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## ECSQ and ECVQ - Precomputed Results

# %%
rates_ECSQ = np.array([2.97740029, 2.5621972 , 2.13101516, 1.8288888 , 1.618663  ,
        1.44212793, 1.30261764, 1.17713086, 1.06186103, 0.92252271,
        0.79000345, 0.64029598, 0.50856324, 0.38279045, 0.27660219,
        0.19148169, 0.11605585, 0.05970051, 0.02240303, 0.01336662])
dists_ECSQ = np.array([0.02800061, 0.04131973, 0.07462458, 0.11369903, 0.15228523,
        0.19310325, 0.23461192, 0.2775388 , 0.32317234, 0.38529088,
        0.45154359, 0.53446308, 0.61424162, 0.69718506, 0.77262514,
        0.83769343, 0.89928998, 0.94832646, 0.98259128, 0.99132379])

rates_ECVQ2 = np.array([2.85622157, 2.5132916 , 2.07947121, 1.8004514 , 1.58576508,
        1.42505262, 1.28840286, 1.17176792, 1.06383905, 0.9454826 ,
        0.80037349, 0.67285   , 0.53958142, 0.40872281, 0.29565961,
        0.1991943 , 0.11953525, 0.05636666, 0.02649921, 0.01027847])
dists_ECVQ2 = np.array([0.03130264, 0.04260418, 0.0763487 , 0.11249734, 0.15164457,
        0.18932363, 0.22880897, 0.26782491, 0.31025808, 0.36326721,
        0.43482761, 0.50516315, 0.58593688, 0.67177034, 0.75270457,
        0.82554378, 0.89040626, 0.94526668, 0.97293568, 0.9885837 ])

rates_ECVQ4 = np.array([2.53482764373767, 2.3344059152146546, 2.0685184291416574, 1.8045403905149953, 1.5766751170386324, 1.4041982198501741, 1.2553188536735085, 1.1444007921445802, 1.0392901108316144, 0.936805925097088, 0.8335176814623515, 0.7096176528387148, 0.5776800539252004, 0.45628835671153184, 0.34028355551055023, 0.23720831218725816, 0.15046527927252742, 0.0851794024863751, 0.03313446276681703, 0.019115288911017513])
dists_ECVQ4 = np.array([0.038651834339326764, 0.048995895614904555, 0.07145984529454297, 0.10531672462534061, 0.14561219529471908, 0.1859906877366243, 0.22650940712330084, 0.2654935833979128, 0.30659674160418726, 0.3509272409389831, 0.4027828595211048, 0.47017744131901723, 0.5497167521843612, 0.6298865426883494, 0.7089442143898945, 0.7878536801252508, 0.8586813379629691, 0.9176006950340156, 0.9624628460189872, 0.9803131704920403])

rates_ECVQ8 = np.array([2.340345481565831, 2.0648261914390544, 1.787612089950559, 1.5630122456624898, 1.3808399666890432, 1.2379215532106846, 1.1169407553230188, 1.0113949059732763, 0.9218638254883185, 0.8338184276290801, 0.7586716215235217, 0.6513994848951441, 0.5496123642309401, 0.4471782693656229, 0.34424438555258086, 0.25115150272476816, 0.16828351086665289, 0.10161310280777233, 0.052688712161688495, 0.026191657288550732])
dists_ECVQ8 = np.array([0.018521685801581977, 0.04550098533124091, 0.08503840486057208, 0.12812689014472867, 0.17271641139914576, 0.21523272352880454, 0.25709584619055276, 0.29907310236708984, 0.339256960259856, 0.38256074815152014, 0.4240648548243452, 0.48678084124496923, 0.5525437369769413, 0.6230628442968745, 0.6986351720251829, 0.7719429287671117, 0.8414492173075865, 0.9001728721223795, 0.9451444708361013, 0.9716562801103614])

# %% [markdown]
# ## LTC with STE and Linear Transforms - Precomputed Results

# %%
rates_NTC = np.array([0.5956760423958365, 1.0488809655336375, 1.2794633184437179, 1.4856456058836214, 1.9628829146533349])
dists_NTC = np.array([0.5594733953475952, 0.3287455141544342, 0.2422681599855423, 0.18273970484733582, 0.09453843533992767])

rates_NTC_2 = np.array([0.0, 0.2812845426044454, 0.8106718693313586, 1.0488809655336375, 1.4928015179443337, 1.991985208282471])
dists_NTC_2 = np.array([1.0, 0.7707668247461319, 0.44090339658260347, 0.3287455141544342, 0.18119327749311925, 0.09062569886446])

rates_Hex = np.array([0.40701484375, 0.501859609375, 0.656805703125, 0.788295234375, 0.988787421875, 1.46233921875, 1.9579446875])
dists_Hex = np.array([0.6732937693595886, 0.6098960638046265, 0.5138776302337646, 0.44215500354766846, 0.3461715579032898, 0.18161945044994354, 0.09153544902801514])

rates_DnDual = np.array([0.09071855333691499, 0.27838148757555414, 0.4715894565102011, 0.7333644404064199, 0.9459606792878581, 1.4143277284235092, 1.9186510549761298])
dists_DnDual = np.array([0.9145929217338562, 0.7598158717155457, 0.6212373971939087, 0.4596688747406006, 0.34985125064849854, 0.18449784815311432, 0.09185788780450821])

rates_E8 = np.array([0.3462104760360707, 0.48079541992187486, 0.5740890913391102, 0.7625981886291504, 0.9047315408325194, 1.3799586994934074, 1.8824865248107903])
dists_E8 = np.array([0.6998485003113747, 0.601594865322113, 0.5379388107657432, 0.42365430483222005, 0.3497181568145752, 0.1812872477322817, 0.09038408526778222])

rates_BW16 = np.array([0.410315078125, 0.5374809375, 0.61199078125, 0.76593015625, 0.91053609375, 1.3535640625, 1.84530046875])
dists_BW16 = np.array([0.6633063554763794, 0.5678021311759949, 0.5156372785568237, 0.41706985235214233, 0.33779704570770264, 0.1804070770740509, 0.09117347002029419])

rates_L24 = np.array([0.33129393229166665, 0.45406536458333335, 0.5415176041666667, 0.6924499479166667, 0.8423921875, 1.3240177083333333, 1.8206522916666668])
dists_L24 = np.array([0.7031254172325134, 0.6053350567817688, 0.5410223007202148, 0.4381854832172394, 0.35422173142433167, 0.1814381331205368, 0.0914095938205719])

rates_ECLQ_Hex = [2.106, 1.5869513324737536, 1.2393663986969001, 0.7156525374984752, 0.3376681692934038, 0.2552678730487822]
dists_ECLQ_Hex = [0.08036, 0.1804007430560887, 0.3192570724785328, 0.6414564654231072, 0.8662983129024505, 0.9969654136002064]

rates_ECLQ_E8 = [2.099503422622679, 1.5733771978759796, 1.233293177604676, 0.7523071239089958, 0.29221590190410646, 0.004405859561710382]
dists_ECLQ_E8 = [0.07158715755864978, 0.16138789558410643, 0.2869835625141859, 0.6224836112856865, 0.8952519467175006, 1.001716995984316]

rates_ECLQ_L24 = [2.0961052666219078, 1.5651321895345074, 1.2212204216003406, 0.7986921674346914, 0.31237126363754275, 0.006525825665434835]
dists_ECLQ_L24 = [0.06572432642802596, 0.1479360300824046, 0.26313523116707804, 0.5890464925169945, 0.9142550658881664, 1.0015686966478825]

# %%
def psnr(dists):
    return 10*np.log10(1 / np.array(dists))
plt.figure(figsize=(6,4), constrained_layout=True)
p1 = plt.plot(rates_ECSQ[:], psnr(dists_ECSQ[:]), '-', fillstyle='none', visible=True)
p2 = plt.plot(rates_ECVQ2[:], psnr(dists_ECVQ2[:]), '-', fillstyle='none', visible=True)
p4 = plt.plot(rates_ECVQ4[:], psnr(dists_ECVQ4[:]), '-', fillstyle='none', visible=True)
p8 = plt.plot(rates_ECVQ8[5:], psnr(dists_ECVQ8[5:]), '-', fillstyle='none', visible=True)
p16 = plt.plot(rates_ECSQ[5:], psnr(dists_ECSQ[5:]), '-', alpha=0, fillstyle='none', visible=False)
p24 = plt.plot(rates_ECSQ[5:], psnr(dists_ECSQ[5:]), '-', alpha=0, fillstyle='none', visible=False)
dists_RD = np.linspace(0.05, 0.9, 20)
rates_RD = 0.5*np.log2(1 / dists_RD)
plt.plot(rates_RD, psnr(dists_RD), '-', c='k', label=r'$R(D)$')
plt.plot(rates_NTC, psnr(dists_NTC), ':s', color=p1[0].get_color(), fillstyle='full', label=r'NTC')
plt.plot(rates_Hex, psnr(dists_Hex), ':^', color=p2[0].get_color(), fillstyle='full', label=r'$n=2$ Hex LTC')
plt.plot(rates_DnDual, psnr(dists_DnDual), ':d', color=p4[0].get_color(), fillstyle='full', label=r'$n=4$ $D_n^*$ LTC')
plt.plot(rates_E8, psnr(dists_E8), ':*', color=p8[0].get_color(), fillstyle='full', label=r'$n=8$ $E_8$ LTC')
plt.plot(rates_BW16, psnr(dists_BW16), ':p', color=p16[0].get_color(), fillstyle='full', label=r'$n=16$ $\Lambda_{24}$ LTC')
plt.plot(rates_L24, psnr(dists_L24), ':X', color=p24[0].get_color(), fillstyle='full', label=r'$n=24$ $\Lambda_{24}$ LTC')
plt.ylabel(r'SNR (dB)', fontsize=20)
plt.xlabel(r'$R$ (bits per sample)', fontsize=20)
plt.legend(fontsize=14)
plt.xlim([0.35, 2.])
plt.ylim([1.5, 10.5])
plt.grid(visible=True)
